# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def func(num,m1,m2):
  sum_list=[]
  sum=0
  for n in range(num):
    if n%3 == 0 or n % 5==0:
      sum+=n
  return sum

print(func(1000, 3,5))
# Out:
# 233168
