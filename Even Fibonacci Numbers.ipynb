# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def func(max):

  num,new=1,2
  total=0

  while num<=max:

   if num % 2 == 0:
    total+=num
   num, new=new, num+new

  print(total)


func(4000000)
# Out:
# 4613732
